# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5.git

# %%
# %cd /content/yolov5/
# !pip install -r requirements.txt

# %%
# %cat /content/drive/MyDrive/Colab_Notebooks/dataset2/data2.yaml

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/yolov5/

# !python train.py --img 416 --batch 50 --epochs 40 --data /content/drive/MyDrive/Colab_Notebooks/dataset2/data2.yaml --cfg ./models/yolov5s.yaml --weights /content/drive/MyDrive/Colab_Notebooks/yolov5/runs/train/helmet_yolov5s_results/weights/best.pt --name KickBoard_V1_yolov5s_results

# %%
 # %load_ext tensorboard
 # %tensorboard --logdir /content/drive/MyDrive/Colab_Notebooks/yolov5/runs/train/KickBoard_V1_yolov5s_results3/

# %%
from IPython.display import Image
import os 

# !python detect.py --weights /content/drive/MyDrive/Colab_Notebooks/yolov5/runs/train/helmet_yolov5s_results/weights/best.pt --img 416 --conf 0.5 --source /content/drive/MyDrive/Colab_Notebooks/dataset/img1/

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/yolov5/

from IPython.display import Image
import os 
test_num = 2
test_img = f'test{test_num}.jpg'
test_img_path = os.path.join('/content/drive/MyDrive/Colab_Notebooks/dataset2/', test_img)
# !python detect.py --weights /content/drive/MyDrive/Colab_Notebooks/yolov5/runs/train/KickBoard_V1_yolov5s_results3/weights/best.pt --img 416 --conf 0.5 --source '{test_img_path}'
Image(os.path.join(f'/content/drive/MyDrive/Colab_Notebooks/yolov5/runs/detect/exp{test_num}/', test_img) )

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/yolov5/

from IPython.display import Image
import os 
test_num = 5
test_img = f'test{test_num}.jpg'
test_img_path = os.path.join('/content/drive/MyDrive/Colab_Notebooks/dataset2/', test_img)
# !python detect.py --weights /content/drive/MyDrive/Colab_Notebooks/yolov5/runs/train/parking_results/weights/best.pt --img 416 --conf 0.4 --source '{test_img_path}'
Image(os.path.join(f'/content/drive/MyDrive/Colab_Notebooks/yolov5/runs/detect/exp{test_num}/', test_img) )
