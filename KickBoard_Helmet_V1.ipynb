# %%
# %cat /content/drive/MyDrive/Colab_Notebooks/dataset2/data2.yaml
# Out:
# train: /content/drive/MyDrive/Colab_Notebooks/dataset2/train/images/*.jpg
# val: /content/drive/MyDrive/Colab_Notebooks/dataset2/test/images/*.jpg
#
# nc: 3
# names: ['head', 'helmet', 'person']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/yolov5/

# !python train.py --img 416 --batch 50 --epochs 40 --data /content/drive/MyDrive/Colab_Notebooks/dataset2/data2.yaml --cfg ./models/yolov5s.yaml --weights /content/drive/MyDrive/Colab_Notebooks/yolov5/runs/train/helmet_yolov5s_results/weights/best.pt --name KickBoard_V1_yolov5s_results
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/ColabNotebooks/yolov5/'
# /content
# python3: can't open file 'train.py': [Errno 2] No such file or directory

# %%
 # %load_ext tensorboard
 # %tensorboard --logdir /content/drive/MyDrive/Colab_Notebooks/yolov5/runs/train/KickBoard_V1_yolov5s_results3/

# %%
from IPython.display import Image
import os 

val_img_path = test_img_list[3]

# !python detect.py --weights /content/yolov5/runs/train/helmet_yolov5s_results/weights/best.pt --img 416 --conf 0.5 --source "{val_img_path}"
# Out:
# detect: weights=['/content/yolov5/runs/train/helmet_yolov5s_results/weights/best.pt'], source=/content/dataset/test/images/005505_jpg.rf.60f4b52ca9a89045308b5fc6405f9cc5.jpg, imgsz=416, conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-351-ge96c74b torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7059304 parameters, 0 gradients, 16.3 GFLOPs
# image 1/1 /content/dataset/test/images/005505_jpg.rf.60f4b52ca9a89045308b5fc6405f9cc5.jpg: 416x416 4 helmets, Done. (0.010s)
# Results saved to runs/detect/exp
# Done. (0.037s)

# %%
 # %cat /content/drive/MyDrive/ColabNotebooks/dataset2/README.dataset.txt
# Out:
# cat: /content/drive/MyDrive/ColabNotebooks/dataset2/README.dataset.txt: No such file or directory

# %%
from IPython.display import Image
import os 

# !python detect.py --weights /content/drive/MyDrive/Colab_Notebooks/yolov5/runs/train/helmet_yolov5s_results/weights/best.pt --img 416 --conf 0.5 --source /content/drive/MyDrive/Colab_Notebooks/dataset/test/images/
# Out:
# detect: weights=['/content/drive/MyDrive/Colab_Notebooks/yolov5/runs/train/helmet_yolov5s_results/weights/best.pt'], source=/content/drive/MyDrive/Colab_Notebooks/dataset/test/images/, imgsz=416, conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-351-ge96c74b torch 1.9.0+cu102 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7059304 parameters, 0 gradients, 16.3 GFLOPs
# image 1/1766 /content/drive/MyDrive/Colab_Notebooks/dataset/test/images/005298_jpg.rf.7d1070e4a462d4c636a68e64f2013761.jpg: 416x416 7 helmets, Done. (0.007s)
# ...

# %%
from IPython.display import Image
import os 

# !python detect.py --weights /content/drive/MyDrive/Colab_Notebooks/yolov5/runs/train/helmet_yolov5s_results/weights/best.pt --img 416 --conf 0.5 --source /content/drive/MyDrive/Colab_Notebooks/dataset/img1/
# Out:
# detect: weights=['/content/drive/MyDrive/Colab_Notebooks/yolov5/runs/train/helmet_yolov5s_results/weights/best.pt'], source=/content/drive/MyDrive/Colab_Notebooks/dataset/img1/, imgsz=416, conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-351-ge96c74b torch 1.9.0+cu102 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7059304 parameters, 0 gradients, 16.3 GFLOPs
# image 1/501 /content/drive/MyDrive/Colab_Notebooks/dataset/img1/helmet1.jpg: 416x416 1 helmet, Done. (0.007s)
# image 2/501 /content/drive/MyDrive/Colab_Notebooks/dataset/img1/helmet10.jpg: 416x416 1 helmet, Done. (0.007s)
# ...

# %%
# %cat /content/drive/MyDrive/Colab_Notebooks/dataset/magic.yaml
# Out:
# magic:
#   train: ../train/images
#   val: ../valid/images
#
#   nc: 3
#   names: ['head', 'helmet', 'person']

# %%
from IPython.display import Image
import os 

# !python detect.py --weights /content/drive/MyDrive/Colab_Notebooks/yolov5/runs/train/KickBoard_V1_yolov5s_results3/weights/best.pt --img 416 --conf 0.5 --source /content/drive/MyDrive/Colab_Notebooks/dataset2/test4.jpg
# Out:
# detect: weights=['/content/drive/MyDrive/Colab_Notebooks/yolov5/runs/train/KickBoard_V1_yolov5s_results3/weights/best.pt'], source=/content/drive/MyDrive/Colab_Notebooks/dataset2/test4.jpg, imgsz=416, conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-351-ge96c74b torch 1.9.0+cu102 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7059304 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/Colab_Notebooks/dataset2/test4.jpg: 416x416 1 head, Done. (0.007s)
# Results saved to runs/detect/exp11
# Done. (0.343s)
